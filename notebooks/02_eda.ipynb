# %% [markdown]
# # Notebook 02 - EDA

# %% [markdown]
# ## Importando dataframe do notebook1

# %%
import pandas as pd

df = pd.read_parquet('../data/raw/train.parquet')

df.head()
# Out:
#    idade tem_carro tem_casa  numero_de_filhos  renda_anual  dias_no_emprego  \
# 0     46         N        Y               0.0    107934.04            612.0
# 1     29         N        Y               0.0    109862.62           2771.0
# 2     37         N        Y               0.0    230153.17            204.0
# 3     39         N        Y               0.0    122325.82          11941.0
# 4     46         Y        Y               0.0    387286.00           1459.0
#
#   tipo_de_profissão  total_membros_familia  imigrante  \
# 0           Unknown                    1.0        1.0
# 1          Laborers                    2.0        0.0
# 2          Laborers                    2.0        0.0
# 3        Core staff                    2.0        0.0
# 4        Core staff                    1.0        0.0
#
#    pagamento_anual_de_debitos    limite  porcentagem_uso_credito  \
# 0                    33070.28  18690.93                       73
# ...

# %% [markdown]
# ## Análise da Variável Alvo
