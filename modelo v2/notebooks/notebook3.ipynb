# %% [markdown]
# # Notebook 3 - Machine Learning

# %% [markdown]
# ## Importando bibliotecas necessárias

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from narwhals import read_parquet

from sqlalchemy import create_engine

from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %% [markdown]
# ## Importando o arquivo .parquet da camada silver

# %%
data = pd.read_parquet("../data/silver/analise_credito_processados.parquet")

data.head()
# Out:
#    Inadimplente  UtilizacaoCredito  Idade  Atraso30_59Dias  TaxaEndividamento  \
# 0             1           0.766127     45                2           0.802982
# 1             0           0.957151     40                0           0.121876
# 2             0           0.658180     38                1           0.085113
# 3             0           0.233810     30                0           0.036050
# 4             0           0.907239     49                1           0.024926
#
#    RendaMensal  NumEmprestimosAbertos  Atraso90MaisDias  \
# 0       9120.0                     13                 0
# 1       2600.0                      4                 0
# 2       3042.0                      2                 1
# 3       3300.0                      5                 0
# 4      63588.0                      7                 0
#
#    NumEmprestimosImobiliarios  Atraso60_89Dias  ...  CapacidadePagamento  \
# 0                           6                0  ...          2132.925326
# ...

# %% [markdown]
# ## Feature Selection

# %%
colunas_para_manter = [
    "Inadimplente",
    'TemAtrasosGraves',
    'TemHistoricoAtraso',
    'NivelUtilizacaoCredito_Encoded',
    'UtilizacaoCredito',
    'Idade',
    'FaixaEtaria_Encoded',
    'RazaoDebitoRenda',
    'CapacidadePagamento'
]

df = data[colunas_para_manter]
df.head()
# Out:
#    Inadimplente  TemAtrasosGraves  TemHistoricoAtraso  \
# 0             1                 0                   1
# 1             0                 0                   0
# 2             0                 1                   1
# 3             0                 0                   0
# 4             0                 0                   1
#
#    NivelUtilizacaoCredito_Encoded  UtilizacaoCredito  Idade  \
# 0                             2.0           0.766127     45
# 1                             3.0           0.957151     40
# 2                             2.0           0.658180     38
# 3                             0.0           0.233810     30
# 4                             3.0           0.907239     49
#
#    FaixaEtaria_Encoded  RazaoDebitoRenda  CapacidadePagamento
# 0                  2.0          0.000084          2132.925326
# 1                  2.0          0.000368           111.407351
# 2                  2.0          0.000216          1039.816014
# ...

# %% [markdown]
# ## Tratando outliers
